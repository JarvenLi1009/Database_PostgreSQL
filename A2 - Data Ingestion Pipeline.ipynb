# %% [markdown]
# # Assignment 2 - Data Ingestion Pipeline

# %% [markdown]
# ## Group Member: Yuntong Zhu; Wei Lu; Xinyuan Liang; Jiawen Li

# %% [markdown]
# ### A brief description of our data source
#
# Our dataset is provided in the Ontario Data Catalog, which contains information on violent crime rates in Ontario from 2008 to 2012. The dataset is available in CSV format.
#
# The dataset includes data related to all types of violent crime under the Criminal Code. Specifically, it covers the following types of violent crime:
#
# Homicide; Attempted murder; Sexual assault (levels 1-3); Assault; Robbery; Criminal Harassment; Making threats; Other Violent Assault
#
# The columns of the dataset include information on the year of observation, the area in which the crime occurred, and the corresponding crime rates for different types of violent crime.

# %%
import sqlalchemy as sa
import pandas as pd
import requests, json

# %% [markdown]
# ### Prepare a GET request to pull the data

# %% [markdown]
# #### Specify the data source including the resource_id, the number of record, and the url link of the api from the data source on website

# %% [markdown]
# URL used to pull the data:
#
# https://data.ontario.ca/api/3/action/datastore_search?resource_id=574e4981-aeff-45bb-9794-a9ed56df5042&limit=5

# %%
resource_id = '574e4981-aeff-45bb-9794-a9ed56df5042' 
limit=1500
api_url = 'https://data.ontario.ca/api/3/action/datastore_search?resource_id={}&limit={}'.format(resource_id, limit)

print(api_url)
# Out:
# https://data.ontario.ca/api/3/action/datastore_search?resource_id=574e4981-aeff-45bb-9794-a9ed56df5042&limit=1500

# %%
# Get the data from the source of website
data = requests.get(api_url)

# %%
data
# Out:
# <Response [200]>

# %%
# Store the data into the notebook using json
data = data.json()
data
# Out:
# {'help': 'https://data.ontario.ca/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 1500,
#   'records_format': 'objects',
#   'resource_id': '574e4981-aeff-45bb-9794-a9ed56df5042',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Geography (Footnotes in parentheses–see bottom of spreadsheet)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Violations (Footnotes in parentheses–see bottom of spreadsheet)',
#     '2008': '2008',
#     '2009': '2009',
#     '2010': '2010',
#     '2011': '2011',
#     '2012': '2012'},
#    {'_id': 2,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#     '2008': '1331.45',
#     '2009': '1318.04',
#     '2010': '1287.03',
#     '2011': '1230.54',
#     '2012': '1190.12'},
#    {'_id': 3,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#     '2008': '1.83',
#     '2009': '1.81',
#     '2010': '1.62',
#     '2011': '1.73',
#     '2012': '1.56'},
#    {'_id': 4,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#     '2008': '0.88',
#     '2009': '0.83',
#     '2010': '0.73',
#     '2011': '0.76',
#     '2012': '0.7'},
#    {'_id': 5,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#     '2008': '0.79',
#     '2009': '0.77',
#     '2010': '0.7',
#     '2011': '0.77',
#     '2012': '0.66'},
#    {'_id': 6,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#     '2008': '0.17',
#     '2009': '0.21',
#     '2010': '0.18',
#     '2011': '0.2',
#     '2012': '0.19'},
#    {'_id': 7,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0.01',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 8,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#     '2008': '0.28',
#     '2009': '0.3',
#     '2010': '0.29',
#     '2011': '0.22',
#     '2012': '0.28'},
#    {'_id': 9,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#     '2008': '0.27',
#     '2009': '0.28',
#     '2010': '0.28',
#     '2011': '0.21',
#     '2012': '0.27'},
#    {'_id': 10,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#     '2008': '0.01',
#     '2009': '0.02',
#     '2010': '0.01',
#     '2011': '0.01',
#     '2012': '0.01'},
#    {'_id': 11,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#     '2008': '2.16',
#     '2009': '2.37',
#     '2010': '1.96',
#     '2011': '1.93',
#     '2012': '1.94'},
#    {'_id': 12,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#     '2008': '0.42',
#     '2009': '0.35',
#     '2010': '0.52',
#     '2011': '0.43',
#     '2012': '0.37'},
#    {'_id': 13,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#     '2008': '1.05',
#     '2009': '1.04',
#     '2010': '1.18',
#     '2011': '1.16',
#     '2012': '1.06'},
#    {'_id': 14,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#     '2008': '62.98',
#     '2009': '60.63',
#     '2010': '63.87',
#     '2011': '61.8',
#     '2012': '61.42'},
#    {'_id': 15,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#     '2008': '4.31',
#     '2009': '7.98',
#     '2010': '10.8',
#     '2011': '11.03',
#     '2012': '11.38'},
#    {'_id': 16,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#     '2008': '2.32',
#     '2009': '5.11',
#     '2010': '7.28',
#     '2011': '7.3',
#     '2012': '7.48'},
#    {'_id': 17,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#     '2008': '0.75',
#     '2009': '1.3',
#     '2010': '1.64',
#     '2011': '1.75',
#     '2012': '1.7'},
#    {'_id': 18,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#     '2008': '0.31',
#     '2009': '0.32',
#     '2010': '0.38',
#     '2011': '0.34',
#     '2012': '0.31'},
#    {'_id': 19,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#     '2008': None,
#     '2009': None,
#     '2010': None,
#     '2011': None,
#     '2012': '0.03'},
#    {'_id': 20,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#     '2008': '0.92',
#     '2009': '1.25',
#     '2010': '1.5',
#     '2011': '1.65',
#     '2012': '1.85'},
#    {'_id': 21,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#     '2008': '10.78',
#     '2009': '10.73',
#     '2010': '10.2',
#     '2011': '10.23',
#     '2012': '10.07'},
#    {'_id': 22,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#     '2008': '164.56',
#     '2009': '158.28',
#     '2010': '152.24',
#     '2011': '146.24',
#     '2012': '142.02'},
#    {'_id': 23,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 1',
#     '2008': '543.29',
#     '2009': '535.37',
#     '2010': '513.64',
#     '2011': '501.97',
#     '2012': '487.37'},
#    {'_id': 24,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total assaults against a peace officer (25,35)',
#     '2008': '29.43',
#     '2009': '35.1',
#     '2010': '46.63',
#     '2011': '33.13',
#     '2012': '30.42'},
#    {'_id': 25,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other assaults',
#     '2008': '11.63',
#     '2009': '10.16',
#     '2010': '9.61',
#     '2011': '8.66',
#     '2012': '8.33'},
#    {'_id': 26,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Unlawfully causing bodily harm',
#     '2008': '1.53',
#     '2009': '1.64',
#     '2010': '1.56',
#     '2011': '1.34',
#     '2012': '1.43'},
#    {'_id': 27,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing bodily harm',
#     '2008': '0.75',
#     '2009': '0.77',
#     '2010': '0.78',
#     '2011': '0.93',
#     '2012': '0.64'},
#    {'_id': 28,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other assaults',
#     '2008': '9.35',
#     '2009': '7.75',
#     '2010': '7.27',
#     '2011': '6.39',
#     '2012': '6.25'},
#    {'_id': 29,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total firearms; use of, discharge, pointing',
#     '2008': '4.44',
#     '2009': '5.15',
#     '2010': '5.91',
#     '2011': '5.64',
#     '2012': '5.85'},
#    {'_id': 30,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Discharge firearm with intent',
#     '2008': '1.26',
#     '2009': '1.58',
#     '2010': '1.81',
#     '2011': '1.65',
#     '2012': '1.83'},
#    {'_id': 31,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Using firearm in commission of offence',
#     '2008': '1.02',
#     '2009': '1.16',
#     '2010': '1.21',
#     '2011': '1.22',
#     '2012': '1.24'},
#    {'_id': 32,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Pointing a firearm',
#     '2008': '2.16',
#     '2009': '2.41',
#     '2010': '2.88',
#     '2011': '2.77',
#     '2012': '2.78'},
#    {'_id': 33,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total robbery (18)',
#     '2008': '97.16',
#     '2009': '96.25',
#     '2010': '89.31',
#     '2011': '86.39',
#     '2012': '79.36'},
#    {'_id': 34,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery (18)',
#     '2008': '97.16',
#     '2009': '96.24',
#     '2010': '89.26',
#     '2011': '86.34',
#     '2012': '79.32'},
#    {'_id': 35,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery to steal a firearm (18)',
#     '2008': '0',
#     '2009': '0.01',
#     '2010': '0.04',
#     '2011': '0.05',
#     '2012': '0.04'},
#    {'_id': 36,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total forcible confinement or kidnapping (34)',
#     '2008': '14.2',
#     '2009': '14.21',
#     '2010': '12.6',
#     '2011': '10.96',
#     '2012': '10.35'},
#    {'_id': 37,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement or kidnapping (34)',
#     '2008': '13.97',
#     '2009': '12.71',
#     '2010': '6.02',
#     '2011': '1.61',
#     '2012': '1.04'},
#    {'_id': 38,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Kidnapping (34)',
#     '2008': '0.03',
#     '2009': '0.16',
#     '2010': '0.8',
#     '2011': '0.88',
#     '2012': '0.83'},
#    {'_id': 39,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement (34)',
#     '2008': '0.21',
#     '2009': '1.34',
#     '2010': '5.78',
#     '2011': '8.48',
#     '2012': '8.47'},
#    {'_id': 40,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total abduction',
#     '2008': '1.38',
#     '2009': '1.29',
#     '2010': '1.32',
#     '2011': '1.17',
#     '2012': '1.12'},
#    {'_id': 41,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14, not parent or guardian',
#     '2008': '0.6',
#     '2009': '0.5',
#     '2010': '0.5',
#     '2011': '0.4',
#     '2012': '0.43'},
#    {'_id': 42,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 16',
#     '2008': '0.14',
#     '2009': '0.12',
#     '2010': '0.12',
#     '2011': '0.11',
#     '2012': '0.11'},
#    {'_id': 43,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Removal of children from Canada',
#     '2008': '0.02',
#     '2009': '0.02',
#     '2010': '0.01',
#     '2011': '0.06',
#     '2012': '0.02'},
#    {'_id': 44,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14 contravening a custody order',
#     '2008': '0.38',
#     '2009': '0.41',
#     '2010': '0.42',
#     '2011': '0.34',
#     '2012': '0.33'},
#    {'_id': 45,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under age 14, by parent or guardian',
#     '2008': '0.24',
#     '2009': '0.24',
#     '2010': '0.26',
#     '2011': '0.27',
#     '2012': '0.23'},
#    {'_id': 46,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Extortion',
#     '2008': '4.21',
#     '2009': '5.09',
#     '2010': '4.62',
#     '2011': '4.43',
#     '2012': '4.91'},
#    {'_id': 47,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal harassment (36)',
#     '2008': '55.68',
#     '2009': '58.88',
#     '2010': '62.46',
#     '2011': '63.08',
#     '2012': '63.65'},
#    {'_id': 48,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Uttering threats',
#     '2008': '237.22',
#     '2009': '233.2',
#     '2010': '223.72',
#     '2011': '208.15',
#     '2012': '201.78'},
#    {'_id': 49,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Threatening or harassing phone calls',
#     '2008': '72.95',
#     '2009': '68.75',
#     '2010': '63.31',
#     '2011': '58.75',
#     '2012': '53.65'},
#    {'_id': 50,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violent violations',
#     '2008': '11.48',
#     '2009': '11.08',
#     '2010': '11.22',
#     '2011': '13.44',
#     '2012': '13.25'},
#    {'_id': 51,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Conspire to commit murder',
#     '2008': '0.1',
#     '2009': '0.15',
#     '2010': '0.08',
#     '2011': '0.1',
#     '2012': '0.14'},
#    {'_id': 52,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other sexual violations',
#     '2008': '5.06',
#     '2009': '1.69',
#     '2010': '0.19',
#     '2011': '0.14',
#     '2012': '0.11'},
#    {'_id': 53,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual Exploitation of a person with a disability',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0.05',
#     '2011': '0.06',
#     '2012': '0.1'},
#    {'_id': 54,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Incest',
#     '2008': '0.29',
#     '2009': '0.6',
#     '2010': '0.67',
#     '2011': '0.63',
#     '2012': '0.64'},
#    {'_id': 55,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Corrupting morals of a child',
#     '2008': '0.06',
#     '2009': '0.07',
#     '2010': '0.13',
#     '2011': '0.1',
#     '2012': '0.11'},
#    {'_id': 56,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Anal intercourse',
#     '2008': '0.05',
#     '2009': '0.05',
#     '2010': '0.09',
#     '2011': '0.06',
#     '2012': '0.04'},
#    {'_id': 57,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Bestiality, commit or compel person',
#     '2008': '0.02',
#     '2009': '0.03',
#     '2010': '0.05',
#     '2011': '0.08',
#     '2012': '0.05'},
#    {'_id': 58,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Voyeurism',
#     '2008': '0.87',
#     '2009': '1.13',
#     '2010': '1.27',
#     '2011': '1.75',
#     '2012': '1.83'},
#    {'_id': 59,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trap likely to or causing bodily harm',
#     '2008': '0.01',
#     '2009': '0.01',
#     '2010': '0',
#     '2011': '0.01',
#     '2012': '0.02'},
#    {'_id': 60,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Hostage-taking',
#     '2008': '0.04',
#     '2009': '0.09',
#     '2010': '0.04',
#     '2011': '0.03',
#     '2012': '0.05'},
#    {'_id': 61,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trafficking in persons',
#     '2008': '0.03',
#     '2009': '0.12',
#     '2010': '0.07',
#     '2011': '0.17',
#     '2012': '0.15'},
#    {'_id': 62,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a justice system participant or a journalist',
#     '2008': '0.68',
#     '2009': '1.21',
#     '2010': '1.17',
#     '2011': '1.44',
#     '2012': '1.73'},
#    {'_id': 63,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a non-justice participant',
#     '2008': '0.99',
#     '2009': '2.85',
#     '2010': '3.22',
#     '2011': '3.41',
#     '2012': '3.36'},
#    {'_id': 64,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Explosives causing death or bodily harm',
#     '2008': '0.09',
#     '2009': '0.04',
#     '2010': '0.05',
#     '2011': '0.06',
#     '2012': '0.04'},
#    {'_id': 65,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Arson, disregard for human life',
#     '2008': '1.14',
#     '2009': '0.98',
#     '2010': '1.22',
#     '2011': '1.1',
#     '2012': '1.39'},
#    {'_id': 66,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other violent violations',
#     '2008': '2.05',
#     '2009': '2.04',
#     '2010': '2.91',
#     '2011': '4.29',
#     '2012': '3.48'},
#    {'_id': 67,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#     '2008': '1530.16',
#     '2009': '1508.76',
#     '2010': '1553.12',
#     '2011': '1527.2',
#     '2012': '1538.64'},
#    {'_id': 68,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#     '2008': '0.99',
#     '2009': '0.2',
#     '2010': '0.78',
#     '2011': '0.78',
#     '2012': '0.59'},
#    {'_id': 69,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#     '2008': '0.79',
#     '2009': '0.2',
#     '2010': '0.59',
#     '2011': '0.39',
#     '2012': '0.39'},
#    {'_id': 70,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#     '2008': '0.2',
#     '2009': '0',
#     '2010': '0.2',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 71,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0.19',
#     '2012': '0.2'},
#    {'_id': 72,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 73,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#     '2008': '0',
#     '2009': '0.2',
#     '2010': '0.2',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 74,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#     '2008': '0',
#     '2009': '0.2',
#     '2010': '0.2',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 75,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 76,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#     '2008': '0.39',
#     '2009': '0',
#     '2010': '0.39',
#     '2011': '0.58',
#     '2012': '0'},
#    {'_id': 77,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#     '2008': '0.2',
#     '2009': '0',
#     '2010': '0.2',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 78,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#     '2008': '0.79',
#     '2009': '1.57',
#     '2010': '0',
#     '2011': '0.58',
#     '2012': '1.37'},
#    {'_id': 79,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#     '2008': '82.16',
#     '2009': '69.34',
#     '2010': '71.7',
#     '2011': '62.59',
#     '2012': '71'},
#    {'_id': 80,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#     '2008': '2.37',
#     '2009': '10.21',
#     '2010': '18.36',
#     '2011': '15.4',
#     '2012': '15.6'},
#    {'_id': 81,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#     '2008': '0.59',
#     '2009': '4.71',
#     '2010': '11.33',
#     '2011': '7.6',
#     '2012': '8.19'},
#    {'_id': 82,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#     '2008': '0.79',
#     '2009': '3.34',
#     '2010': '3.13',
#     '2011': '2.92',
#     '2012': '2.54'},
#    {'_id': 83,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#     '2008': '0.39',
#     '2009': '0.2',
#     '2010': '0',
#     '2011': '0.39',
#     '2012': '0.2'},
#    {'_id': 84,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#     '2008': None,
#     '2009': None,
#     '2010': None,
#     '2011': None,
#     '2012': '0'},
#    {'_id': 85,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#     '2008': '0.59',
#     '2009': '1.96',
#     '2010': '3.91',
#     '2011': '4.48',
#     '2012': '4.68'},
#    {'_id': 86,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#     '2008': '5.73',
#     '2009': '6.87',
#     '2010': '5.67',
#     '2011': '6.04',
#     '2012': '5.85'},
#    {'_id': 87,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#     '2008': '142',
#     '2009': '131.21',
#     '2010': '124.45',
#     '2011': '129.65',
#     '2012': '144.93'},
#    {'_id': 88,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 1',
#     '2008': '674.43',
#     '2009': '691.42',
#     '2010': '665.4',
#     '2011': '697.41',
#     '2012': '712.17'},
#    {'_id': 89,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total assaults against a peace officer (25,35)',
#     '2008': '21.33',
#     '2009': '35.95',
#     '2010': '89.48',
#     '2011': '41.14',
#     '2012': '33.36'},
#    {'_id': 90,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other assaults',
#     '2008': '2.37',
#     '2009': '2.95',
#     '2010': '4.69',
#     '2011': '6.63',
#     '2012': '3.9'},
#    {'_id': 91,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Unlawfully causing bodily harm',
#     '2008': '0.2',
#     '2009': '0.59',
#     '2010': '0.2',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 92,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing bodily harm',
#     '2008': '0.39',
#     '2009': '0.39',
#     '2010': '0.98',
#     '2011': '0.39',
#     '2012': '0'},
#    {'_id': 93,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other assaults',
#     '2008': '1.78',
#     '2009': '1.96',
#     '2010': '3.52',
#     '2011': '6.04',
#     '2012': '3.9'},
#    {'_id': 94,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total firearms; use of, discharge, pointing',
#     '2008': '3.95',
#     '2009': '4.71',
#     '2010': '7.62',
#     '2011': '5.65',
#     '2012': '9.36'},
#    {'_id': 95,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Discharge firearm with intent',
#     '2008': '2.76',
#     '2009': '2.36',
#     '2010': '3.13',
#     '2011': '0.97',
#     '2012': '2.93'},
#    {'_id': 96,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Using firearm in commission of offence',
#     '2008': '0',
#     '2009': '0.79',
#     '2010': '1.76',
#     '2011': '2.53',
#     '2012': '3.51'},
#    {'_id': 97,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Pointing a firearm',
#     '2008': '1.18',
#     '2009': '1.57',
#     '2010': '2.74',
#     '2011': '2.14',
#     '2012': '2.93'},
#    {'_id': 98,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total robbery (18)',
#     '2008': '27.06',
#     '2009': '22.79',
#     '2010': '31.65',
#     '2011': '21.45',
#     '2012': '27.7'},
#    {'_id': 99,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery (18)',
#     '2008': '27.06',
#     '2009': '22.79',
#     '2010': '31.65',
#     '2011': '21.45',
#     '2012': '27.7'},
#    {'_id': 100,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery to steal a firearm (18)',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 101,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total forcible confinement or kidnapping (34)',
#     '2008': '8.49',
#     '2009': '10.8',
#     '2010': '11.14',
#     '2011': '6.63',
#     '2012': '7.02'},
#    {'_id': 102,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement or kidnapping (34)',
#     '2008': '8.49',
#     '2009': '10.8',
#     '2010': '9.96',
#     '2011': '1.56',
#     '2012': '0'},
#    {'_id': 103,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Kidnapping (34)',
#     '2008': None,
#     '2009': None,
#     '2010': '0.2',
#     '2011': '0.19',
#     '2012': '0.2'},
#    {'_id': 104,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement (34)',
#     '2008': None,
#     '2009': None,
#     '2010': '0.98',
#     '2011': '4.87',
#     '2012': '6.83'},
#    {'_id': 105,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total abduction',
#     '2008': '1.38',
#     '2009': '0.59',
#     '2010': '1.17',
#     '2011': '1.95',
#     '2012': '1.17'},
#    {'_id': 106,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14, not parent or guardian',
#     '2008': '0.39',
#     '2009': '0.39',
#     '2010': '0.39',
#     '2011': '0.78',
#     '2012': '0.98'},
#    {'_id': 107,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 16',
#     '2008': '0.2',
#     '2009': '0',
#     '2010': '0.2',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 108,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Removal of children from Canada',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 109,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14 contravening a custody order',
#     '2008': '0.59',
#     '2009': '0',
#     '2010': '0.39',
#     '2011': '0',
#     '2012': '0.2'},
#    {'_id': 110,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under age 14, by parent or guardian',
#     '2008': '0.2',
#     '2009': '0.2',
#     '2010': '0.2',
#     '2011': '0.97',
#     '2012': '0'},
#    {'_id': 111,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Extortion',
#     '2008': '0.59',
#     '2009': '0',
#     '2010': '1.76',
#     '2011': '1.36',
#     '2012': '0.78'},
#    {'_id': 112,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal harassment (36)',
#     '2008': '38.91',
#     '2009': '44.98',
#     '2010': '43.57',
#     '2011': '40.75',
#     '2012': '39.21'},
#    {'_id': 113,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Uttering threats',
#     '2008': '349.16',
#     '2009': '358.48',
#     '2010': '374.9',
#     '2011': '385.65',
#     '2012': '389.73'},
#    {'_id': 114,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Threatening or harassing phone calls',
#     '2008': '154.04',
#     '2009': '106.66',
#     '2010': '95.14',
#     '2011': '96.32',
#     '2012': '68.27'},
#    {'_id': 115,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violent violations',
#     '2008': '13.82',
#     '2009': '9.82',
#     '2010': '4.88',
#     '2011': '6.43',
#     '2012': '6.63'},
#    {'_id': 116,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Conspire to commit murder',
#     '2008': '0.2',
#     '2009': '0.39',
#     '2010': '0',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 117,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other sexual violations',
#     '2008': '10.86',
#     '2009': '6.29',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 118,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual Exploitation of a person with a disability',
#     '2008': '0',
#     '2009': '0.2',
#     '2010': '0',
#     '2011': '0.39',
#     '2012': '0.2'},
#    {'_id': 119,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Incest',
#     '2008': '0',
#     '2009': '0.2',
#     '2010': '0.98',
#     '2011': '0.19',
#     '2012': '0.98'},
#    {'_id': 120,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Corrupting morals of a child',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0.2'},
#    {'_id': 121,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Anal intercourse',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0.2',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 122,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Bestiality, commit or compel person',
#     '2008': '0.2',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0.39',
#     '2012': '0'},
#    {'_id': 123,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Voyeurism',
#     '2008': '0',
#     '2009': '0.59',
#     '2010': '0.59',
#     '2011': '0.58',
#     '2012': '0.78'},
#    {'_id': 124,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trap likely to or causing bodily harm',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 125,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Hostage-taking',
#     '2008': '0',
#     '2009': '0.39',
#     '2010': '1.17',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 126,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trafficking in persons',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 127,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a justice system participant or a journalist',
#     '2008': '0.39',
#     '2009': '0',
#     '2010': '0.59',
#     '2011': '0.19',
#     '2012': '0.59'},
#    {'_id': 128,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a non-justice participant',
#     '2008': '0',
#     '2009': '0.2',
#     '2010': '0.2',
#     '2011': '0.97',
#     '2012': '0.59'},
#    {'_id': 129,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Explosives causing death or bodily harm',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0.2',
#     '2011': '0.58',
#     '2012': '0'},
#    {'_id': 130,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Arson, disregard for human life',
#     '2008': '0.59',
#     '2009': '0.59',
#     '2010': '0',
#     '2011': '0.78',
#     '2012': '0.59'},
#    {'_id': 131,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other violent violations',
#     '2008': '1.58',
#     '2009': '0.98',
#     '2010': '0.98',
#     '2011': '2.14',
#     '2012': '2.73'},
#    {'_id': 132,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#     '2008': '1142.26',
#     '2009': '1264.76',
#     '2010': '1173.49',
#     '2011': '1143.48',
#     '2012': '1168.34'},
#    {'_id': 133,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#     '2008': '1.43',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0.69',
#     '2012': '0'},
#    {'_id': 134,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0.69',
#     '2012': '0'},
#    {'_id': 135,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 136,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#     '2008': '1.43',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 137,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 138,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 139,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 140,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 141,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#     '2008': '0.72',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0.68'},
#    {'_id': 142,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 143,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#     '2008': '0',
#     '2009': '1.42',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0.68'},
#    {'_id': 144,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#     '2008': '55.18',
#     '2009': '43.95',
#     '2010': '42.63',
#     '2011': '50.79',
#     '2012': '49.96'},
#    {'_id': 145,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#     '2008': '1.43',
#     '2009': '12.76',
#     '2010': '16.77',
#     '2011': '13.04',
#     '2012': '15.74'},
#    {'_id': 146,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#     '2008': '0',
#     '2009': '11.34',
#     '2010': '9.78',
#     '2011': '6.86',
#     '2012': '6.16'},
#    {'_id': 147,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '1.37',
#     '2012': '4.11'},
#    {'_id': 148,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0.68'},
#    {'_id': 149,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#     '2008': None,
#     '2009': None,
#     '2010': None,
#     '2011': None,
#     '2012': '0'},
#    {'_id': 150,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#     '2008': '1.43',
#     '2009': '1.42',
#     '2010': '6.99',
#     '2011': '4.8',
#     '2012': '4.79'},
#    {'_id': 151,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#     '2008': '1.43',
#     '2009': '4.96',
#     '2010': '4.19',
#     '2011': '4.8',
#     '2012': '2.05'},
#    {'_id': 152,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#     '2008': '75.24',
#     '2009': '73.73',
#     '2010': '85.27',
#     '2011': '88.54',
#     '2012': '72.55'},
#    {'_id': 153,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
# ...
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 954,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14 contravening a custody order',
#     '2008': '0.2',
#     '2009': '0.19',
#     '2010': '0.19',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 955,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under age 14, by parent or guardian',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0.57',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 956,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Extortion',
#     '2008': '3.71',
#     '2009': '5.22',
#     '2010': '3.82',
#     '2011': '3.77',
#     '2012': '2.42'},
#    {'_id': 957,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal harassment (36)',
#     '2008': '100.28',
#     '2009': '100.95',
#     '2010': '113.66',
#     '2011': '91.29',
#     '2012': '79.73'},
#    {'_id': 958,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Uttering threats',
#     '2008': '125.11',
#     '2009': '139.24',
#     '2010': '149.76',
#     '2011': '147.31',
#     '2012': '137.67'},
#    {'_id': 959,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Threatening or harassing phone calls',
#     '2008': '32.06',
#     '2009': '24.17',
#     '2010': '18.53',
#     '2011': '19.99',
#     '2012': '20.49'},
#    {'_id': 960,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violent violations',
#     '2008': '16.22',
#     '2009': '7.54',
#     '2010': '5.73',
#     '2011': '10.56',
#     '2012': '9.31'},
#    {'_id': 961,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Conspire to commit murder',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0.19',
#     '2012': '0'},
#    {'_id': 962,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other sexual violations',
#     '2008': '13.49',
#     '2009': '0.58',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 963,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual Exploitation of a person with a disability',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 964,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Incest',
#     '2008': '0',
#     '2009': '0.19',
#     '2010': '0.38',
#     '2011': '0.75',
#     '2012': '0.37'},
#    {'_id': 965,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Corrupting morals of a child',
#     '2008': '0',
#     '2009': '0.39',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 966,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Anal intercourse',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 967,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Bestiality, commit or compel person',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0.57',
#     '2012': '0'},
#    {'_id': 968,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Voyeurism',
#     '2008': '0.2',
#     '2009': '2.71',
#     '2010': '0.96',
#     '2011': '6.6',
#     '2012': '4.84'},
#    {'_id': 969,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trap likely to or causing bodily harm',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 970,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Hostage-taking',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 971,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trafficking in persons',
#     '2008': None,
#     '2009': None,
#     '2010': '0.38',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 972,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a justice system participant or a journalist',
#     '2008': '0.39',
#     '2009': '0.58',
#     '2010': '0.38',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 973,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a non-justice participant',
#     '2008': '0',
#     '2009': '0.19',
#     '2010': '0.57',
#     '2011': '1.7',
#     '2012': '0.93'},
#    {'_id': 974,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Explosives causing death or bodily harm',
#     '2008': '0.2',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 975,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Arson, disregard for human life',
#     '2008': '0.59',
#     '2009': '1.35',
#     '2010': '1.53',
#     '2011': '0.19',
#     '2012': '1.86'},
#    {'_id': 976,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other violent violations',
#     '2008': '1.37',
#     '2009': '1.55',
#     '2010': '1.53',
#     '2011': '0.57',
#     '2012': '1.3'},
#    {'_id': 977,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#     '2008': '1629.39',
#     '2009': '1692.62',
#     '2010': '1640.97',
#     '2011': '1443.26',
#     '2012': '1321.5'},
#    {'_id': 978,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#     '2008': '1.45',
#     '2009': '1.44',
#     '2010': '0.72',
#     '2011': '1.42',
#     '2012': '0'},
#    {'_id': 979,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#     '2008': '0',
#     '2009': '1.44',
#     '2010': '0',
#     '2011': '0.71',
#     '2012': '0'},
#    {'_id': 980,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#     '2008': '1.45',
#     '2009': '0',
#     '2010': '0.72',
#     '2011': '0.71',
#     '2012': '0'},
#    {'_id': 981,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 982,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#     '2008': None,
#     '2009': None,
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 983,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#     '2008': '0',
#     '2009': '0.72',
#     '2010': '0.72',
#     '2011': '0.71',
#     '2012': '0.71'},
#    {'_id': 984,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#     '2008': '0',
#     '2009': '0.72',
#     '2010': '0.72',
#     '2011': '0.71',
#     '2012': '0.71'},
#    {'_id': 985,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#     '2008': '0',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 986,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#     '2008': '2.18',
#     '2009': '2.88',
#     '2010': '2.15',
#     '2011': '2.14',
#     '2012': '1.42'},
#    {'_id': 987,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#     '2008': '0.73',
#     '2009': '0',
#     '2010': '0',
#     '2011': '0',
#     '2012': '0.71'},
#    {'_id': 988,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#     '2008': '2.9',
#     '2009': '0.72',
#     '2010': '0.72',
#     '2011': '0.71',
#     '2012': '2.13'},
#    {'_id': 989,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#     '2008': '82.7',
#     '2009': '93.67',
#     '2010': '85.27',
#     '2011': '94.74',
#     '2012': '68.73'},
#    {'_id': 990,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#     '2008': '2.18',
#     '2009': '6.49',
#     '2010': '10.03',
#     '2011': '9.97',
#     '2012': '8.5'},
#    {'_id': 991,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#     '2008': '0',
#     '2009': '2.16',
#     '2010': '5.02',
#     '2011': '4.27',
#     '2012': '7.79'},
#    {'_id': 992,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#     '2008': '0.73',
#     '2009': '2.16',
#     '2010': '2.87',
#     '2011': '4.27',
#     '2012': '0'},
#    {'_id': 993,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#     '2008': '0.73',
#     '2009': '0',
#     '2010': '0.72',
#     '2011': '0',
#     '2012': '0'},
#    {'_id': 994,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#     '2008': None,
#     '2009': None,
#     '2010': None,
#     '2011': None,
#     '2012': '0'},
#    {'_id': 995,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#     '2008': '0.73',
#     '2009': '2.16',
#     '2010': '1.43',
#     '2011': '1.42',
#     '2012': '0.71'},
#    {'_id': 996,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#     '2008': '7.98',
#     '2009': '10.09',
#     '2010': '13.61',
#     '2011': '9.97',
#     '2012': '10.63'},
#    {'_id': 997,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#     '2008': '153.8',
#     '2009': '145.56',
#     '2010': '173.41',
#     '2011': '123.95',
#     '2012': '125.42'},
#    {'_id': 998,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 1',
#     '2008': '692.82',
#     '2009': '682.38',
#     '2010': '688.63',
#     '2011': '641.13',
#     '2012': '586.7'},
#    {'_id': 999,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total assaults against a peace officer (25,35)',
#     '2008': '28.29',
#     '2009': '33.87',
#     '2010': '35.83',
#     '2011': '27.07',
#     '2012': '18.42'},
#    {'_id': 1000,
#     'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#     'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other assaults',
#     '2008': '18.86',
#     '2009': '37.47',
#     '2010': '56.61',
#     '2011': '29.92',
#     '2012': '37.55'},
#    ...],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'Geography (Footnotes in parentheses-see bottom of spreadsheet)',
#     'type': 'text'},
#    {'id': 'Violations (Footnotes in parentheses-see bottom of spreadsheet)',
#     'type': 'text'},
#    {'id': '2008', 'type': 'text'},
#    {'id': '2009', 'type': 'text'},
#    {'id': '2010', 'type': 'text'},
#    {'id': '2011', 'type': 'text'},
#    {'id': '2012', 'type': 'text'}],
#   '_links': {'start': '/api/3/action/datastore_search?resource_id=574e4981-aeff-45bb-9794-a9ed56df5042&limit=1500',
#    'next': '/api/3/action/datastore_search?resource_id=574e4981-aeff-45bb-9794-a9ed56df5042&limit=1500&offset=1500'},
#   'total': 1913,
#   'total_was_estimated': False}}

# %%
# Extract specific columns you are interested in from the dataset
# extract the columns, form a dataset and name it as violent crime rate dataset, abbreviated as violent_cr_data
violent_cr_data = data['result']['records']

# %%
violent_cr_data
# Out:
# [{'_id': 1,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Geography (Footnotes in parentheses–see bottom of spreadsheet)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Violations (Footnotes in parentheses–see bottom of spreadsheet)',
#   '2008': '2008',
#   '2009': '2009',
#   '2010': '2010',
#   '2011': '2011',
#   '2012': '2012'},
#  {'_id': 2,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#   '2008': '1331.45',
#   '2009': '1318.04',
#   '2010': '1287.03',
#   '2011': '1230.54',
#   '2012': '1190.12'},
#  {'_id': 3,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#   '2008': '1.83',
#   '2009': '1.81',
#   '2010': '1.62',
#   '2011': '1.73',
#   '2012': '1.56'},
#  {'_id': 4,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#   '2008': '0.88',
#   '2009': '0.83',
#   '2010': '0.73',
#   '2011': '0.76',
#   '2012': '0.7'},
#  {'_id': 5,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#   '2008': '0.79',
#   '2009': '0.77',
#   '2010': '0.7',
#   '2011': '0.77',
#   '2012': '0.66'},
#  {'_id': 6,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#   '2008': '0.17',
#   '2009': '0.21',
#   '2010': '0.18',
#   '2011': '0.2',
#   '2012': '0.19'},
#  {'_id': 7,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0.01',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 8,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#   '2008': '0.28',
#   '2009': '0.3',
#   '2010': '0.29',
#   '2011': '0.22',
#   '2012': '0.28'},
#  {'_id': 9,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#   '2008': '0.27',
#   '2009': '0.28',
#   '2010': '0.28',
#   '2011': '0.21',
#   '2012': '0.27'},
#  {'_id': 10,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#   '2008': '0.01',
#   '2009': '0.02',
#   '2010': '0.01',
#   '2011': '0.01',
#   '2012': '0.01'},
#  {'_id': 11,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#   '2008': '2.16',
#   '2009': '2.37',
#   '2010': '1.96',
#   '2011': '1.93',
#   '2012': '1.94'},
#  {'_id': 12,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#   '2008': '0.42',
#   '2009': '0.35',
#   '2010': '0.52',
#   '2011': '0.43',
#   '2012': '0.37'},
#  {'_id': 13,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#   '2008': '1.05',
#   '2009': '1.04',
#   '2010': '1.18',
#   '2011': '1.16',
#   '2012': '1.06'},
#  {'_id': 14,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#   '2008': '62.98',
#   '2009': '60.63',
#   '2010': '63.87',
#   '2011': '61.8',
#   '2012': '61.42'},
#  {'_id': 15,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#   '2008': '4.31',
#   '2009': '7.98',
#   '2010': '10.8',
#   '2011': '11.03',
#   '2012': '11.38'},
#  {'_id': 16,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#   '2008': '2.32',
#   '2009': '5.11',
#   '2010': '7.28',
#   '2011': '7.3',
#   '2012': '7.48'},
#  {'_id': 17,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#   '2008': '0.75',
#   '2009': '1.3',
#   '2010': '1.64',
#   '2011': '1.75',
#   '2012': '1.7'},
#  {'_id': 18,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#   '2008': '0.31',
#   '2009': '0.32',
#   '2010': '0.38',
#   '2011': '0.34',
#   '2012': '0.31'},
#  {'_id': 19,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#   '2008': None,
#   '2009': None,
#   '2010': None,
#   '2011': None,
#   '2012': '0.03'},
#  {'_id': 20,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#   '2008': '0.92',
#   '2009': '1.25',
#   '2010': '1.5',
#   '2011': '1.65',
#   '2012': '1.85'},
#  {'_id': 21,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#   '2008': '10.78',
#   '2009': '10.73',
#   '2010': '10.2',
#   '2011': '10.23',
#   '2012': '10.07'},
#  {'_id': 22,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#   '2008': '164.56',
#   '2009': '158.28',
#   '2010': '152.24',
#   '2011': '146.24',
#   '2012': '142.02'},
#  {'_id': 23,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 1',
#   '2008': '543.29',
#   '2009': '535.37',
#   '2010': '513.64',
#   '2011': '501.97',
#   '2012': '487.37'},
#  {'_id': 24,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total assaults against a peace officer (25,35)',
#   '2008': '29.43',
#   '2009': '35.1',
#   '2010': '46.63',
#   '2011': '33.13',
#   '2012': '30.42'},
#  {'_id': 25,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other assaults',
#   '2008': '11.63',
#   '2009': '10.16',
#   '2010': '9.61',
#   '2011': '8.66',
#   '2012': '8.33'},
#  {'_id': 26,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Unlawfully causing bodily harm',
#   '2008': '1.53',
#   '2009': '1.64',
#   '2010': '1.56',
#   '2011': '1.34',
#   '2012': '1.43'},
#  {'_id': 27,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing bodily harm',
#   '2008': '0.75',
#   '2009': '0.77',
#   '2010': '0.78',
#   '2011': '0.93',
#   '2012': '0.64'},
#  {'_id': 28,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other assaults',
#   '2008': '9.35',
#   '2009': '7.75',
#   '2010': '7.27',
#   '2011': '6.39',
#   '2012': '6.25'},
#  {'_id': 29,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total firearms; use of, discharge, pointing',
#   '2008': '4.44',
#   '2009': '5.15',
#   '2010': '5.91',
#   '2011': '5.64',
#   '2012': '5.85'},
#  {'_id': 30,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Discharge firearm with intent',
#   '2008': '1.26',
#   '2009': '1.58',
#   '2010': '1.81',
#   '2011': '1.65',
#   '2012': '1.83'},
#  {'_id': 31,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Using firearm in commission of offence',
#   '2008': '1.02',
#   '2009': '1.16',
#   '2010': '1.21',
#   '2011': '1.22',
#   '2012': '1.24'},
#  {'_id': 32,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Pointing a firearm',
#   '2008': '2.16',
#   '2009': '2.41',
#   '2010': '2.88',
#   '2011': '2.77',
#   '2012': '2.78'},
#  {'_id': 33,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total robbery (18)',
#   '2008': '97.16',
#   '2009': '96.25',
#   '2010': '89.31',
#   '2011': '86.39',
#   '2012': '79.36'},
#  {'_id': 34,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery (18)',
#   '2008': '97.16',
#   '2009': '96.24',
#   '2010': '89.26',
#   '2011': '86.34',
#   '2012': '79.32'},
#  {'_id': 35,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery to steal a firearm (18)',
#   '2008': '0',
#   '2009': '0.01',
#   '2010': '0.04',
#   '2011': '0.05',
#   '2012': '0.04'},
#  {'_id': 36,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total forcible confinement or kidnapping (34)',
#   '2008': '14.2',
#   '2009': '14.21',
#   '2010': '12.6',
#   '2011': '10.96',
#   '2012': '10.35'},
#  {'_id': 37,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement or kidnapping (34)',
#   '2008': '13.97',
#   '2009': '12.71',
#   '2010': '6.02',
#   '2011': '1.61',
#   '2012': '1.04'},
#  {'_id': 38,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Kidnapping (34)',
#   '2008': '0.03',
#   '2009': '0.16',
#   '2010': '0.8',
#   '2011': '0.88',
#   '2012': '0.83'},
#  {'_id': 39,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement (34)',
#   '2008': '0.21',
#   '2009': '1.34',
#   '2010': '5.78',
#   '2011': '8.48',
#   '2012': '8.47'},
#  {'_id': 40,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total abduction',
#   '2008': '1.38',
#   '2009': '1.29',
#   '2010': '1.32',
#   '2011': '1.17',
#   '2012': '1.12'},
#  {'_id': 41,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14, not parent or guardian',
#   '2008': '0.6',
#   '2009': '0.5',
#   '2010': '0.5',
#   '2011': '0.4',
#   '2012': '0.43'},
#  {'_id': 42,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 16',
#   '2008': '0.14',
#   '2009': '0.12',
#   '2010': '0.12',
#   '2011': '0.11',
#   '2012': '0.11'},
#  {'_id': 43,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Removal of children from Canada',
#   '2008': '0.02',
#   '2009': '0.02',
#   '2010': '0.01',
#   '2011': '0.06',
#   '2012': '0.02'},
#  {'_id': 44,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14 contravening a custody order',
#   '2008': '0.38',
#   '2009': '0.41',
#   '2010': '0.42',
#   '2011': '0.34',
#   '2012': '0.33'},
#  {'_id': 45,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under age 14, by parent or guardian',
#   '2008': '0.24',
#   '2009': '0.24',
#   '2010': '0.26',
#   '2011': '0.27',
#   '2012': '0.23'},
#  {'_id': 46,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Extortion',
#   '2008': '4.21',
#   '2009': '5.09',
#   '2010': '4.62',
#   '2011': '4.43',
#   '2012': '4.91'},
#  {'_id': 47,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal harassment (36)',
#   '2008': '55.68',
#   '2009': '58.88',
#   '2010': '62.46',
#   '2011': '63.08',
#   '2012': '63.65'},
#  {'_id': 48,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Uttering threats',
#   '2008': '237.22',
#   '2009': '233.2',
#   '2010': '223.72',
#   '2011': '208.15',
#   '2012': '201.78'},
#  {'_id': 49,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Threatening or harassing phone calls',
#   '2008': '72.95',
#   '2009': '68.75',
#   '2010': '63.31',
#   '2011': '58.75',
#   '2012': '53.65'},
#  {'_id': 50,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violent violations',
#   '2008': '11.48',
#   '2009': '11.08',
#   '2010': '11.22',
#   '2011': '13.44',
#   '2012': '13.25'},
#  {'_id': 51,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Conspire to commit murder',
#   '2008': '0.1',
#   '2009': '0.15',
#   '2010': '0.08',
#   '2011': '0.1',
#   '2012': '0.14'},
#  {'_id': 52,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other sexual violations',
#   '2008': '5.06',
#   '2009': '1.69',
#   '2010': '0.19',
#   '2011': '0.14',
#   '2012': '0.11'},
#  {'_id': 53,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual Exploitation of a person with a disability',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0.05',
#   '2011': '0.06',
#   '2012': '0.1'},
#  {'_id': 54,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Incest',
#   '2008': '0.29',
#   '2009': '0.6',
#   '2010': '0.67',
#   '2011': '0.63',
#   '2012': '0.64'},
#  {'_id': 55,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Corrupting morals of a child',
#   '2008': '0.06',
#   '2009': '0.07',
#   '2010': '0.13',
#   '2011': '0.1',
#   '2012': '0.11'},
#  {'_id': 56,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Anal intercourse',
#   '2008': '0.05',
#   '2009': '0.05',
#   '2010': '0.09',
#   '2011': '0.06',
#   '2012': '0.04'},
#  {'_id': 57,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Bestiality, commit or compel person',
#   '2008': '0.02',
#   '2009': '0.03',
#   '2010': '0.05',
#   '2011': '0.08',
#   '2012': '0.05'},
#  {'_id': 58,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Voyeurism',
#   '2008': '0.87',
#   '2009': '1.13',
#   '2010': '1.27',
#   '2011': '1.75',
#   '2012': '1.83'},
#  {'_id': 59,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trap likely to or causing bodily harm',
#   '2008': '0.01',
#   '2009': '0.01',
#   '2010': '0',
#   '2011': '0.01',
#   '2012': '0.02'},
#  {'_id': 60,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Hostage-taking',
#   '2008': '0.04',
#   '2009': '0.09',
#   '2010': '0.04',
#   '2011': '0.03',
#   '2012': '0.05'},
#  {'_id': 61,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trafficking in persons',
#   '2008': '0.03',
#   '2009': '0.12',
#   '2010': '0.07',
#   '2011': '0.17',
#   '2012': '0.15'},
#  {'_id': 62,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a justice system participant or a journalist',
#   '2008': '0.68',
#   '2009': '1.21',
#   '2010': '1.17',
#   '2011': '1.44',
#   '2012': '1.73'},
#  {'_id': 63,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a non-justice participant',
#   '2008': '0.99',
#   '2009': '2.85',
#   '2010': '3.22',
#   '2011': '3.41',
#   '2012': '3.36'},
#  {'_id': 64,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Explosives causing death or bodily harm',
#   '2008': '0.09',
#   '2009': '0.04',
#   '2010': '0.05',
#   '2011': '0.06',
#   '2012': '0.04'},
#  {'_id': 65,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Arson, disregard for human life',
#   '2008': '1.14',
#   '2009': '0.98',
#   '2010': '1.22',
#   '2011': '1.1',
#   '2012': '1.39'},
#  {'_id': 66,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Canada (50)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other violent violations',
#   '2008': '2.05',
#   '2009': '2.04',
#   '2010': '2.91',
#   '2011': '4.29',
#   '2012': '3.48'},
#  {'_id': 67,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#   '2008': '1530.16',
#   '2009': '1508.76',
#   '2010': '1553.12',
#   '2011': '1527.2',
#   '2012': '1538.64'},
#  {'_id': 68,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#   '2008': '0.99',
#   '2009': '0.2',
#   '2010': '0.78',
#   '2011': '0.78',
#   '2012': '0.59'},
#  {'_id': 69,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#   '2008': '0.79',
#   '2009': '0.2',
#   '2010': '0.59',
#   '2011': '0.39',
#   '2012': '0.39'},
#  {'_id': 70,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#   '2008': '0.2',
#   '2009': '0',
#   '2010': '0.2',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 71,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0.19',
#   '2012': '0.2'},
#  {'_id': 72,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 73,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#   '2008': '0',
#   '2009': '0.2',
#   '2010': '0.2',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 74,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#   '2008': '0',
#   '2009': '0.2',
#   '2010': '0.2',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 75,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 76,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#   '2008': '0.39',
#   '2009': '0',
#   '2010': '0.39',
#   '2011': '0.58',
#   '2012': '0'},
#  {'_id': 77,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#   '2008': '0.2',
#   '2009': '0',
#   '2010': '0.2',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 78,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#   '2008': '0.79',
#   '2009': '1.57',
#   '2010': '0',
#   '2011': '0.58',
#   '2012': '1.37'},
#  {'_id': 79,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#   '2008': '82.16',
#   '2009': '69.34',
#   '2010': '71.7',
#   '2011': '62.59',
#   '2012': '71'},
#  {'_id': 80,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#   '2008': '2.37',
#   '2009': '10.21',
#   '2010': '18.36',
#   '2011': '15.4',
#   '2012': '15.6'},
#  {'_id': 81,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#   '2008': '0.59',
#   '2009': '4.71',
#   '2010': '11.33',
#   '2011': '7.6',
#   '2012': '8.19'},
#  {'_id': 82,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#   '2008': '0.79',
#   '2009': '3.34',
#   '2010': '3.13',
#   '2011': '2.92',
#   '2012': '2.54'},
#  {'_id': 83,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#   '2008': '0.39',
#   '2009': '0.2',
#   '2010': '0',
#   '2011': '0.39',
#   '2012': '0.2'},
#  {'_id': 84,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#   '2008': None,
#   '2009': None,
#   '2010': None,
#   '2011': None,
#   '2012': '0'},
#  {'_id': 85,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#   '2008': '0.59',
#   '2009': '1.96',
#   '2010': '3.91',
#   '2011': '4.48',
#   '2012': '4.68'},
#  {'_id': 86,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#   '2008': '5.73',
#   '2009': '6.87',
#   '2010': '5.67',
#   '2011': '6.04',
#   '2012': '5.85'},
#  {'_id': 87,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#   '2008': '142',
#   '2009': '131.21',
#   '2010': '124.45',
#   '2011': '129.65',
#   '2012': '144.93'},
#  {'_id': 88,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 1',
#   '2008': '674.43',
#   '2009': '691.42',
#   '2010': '665.4',
#   '2011': '697.41',
#   '2012': '712.17'},
#  {'_id': 89,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total assaults against a peace officer (25,35)',
#   '2008': '21.33',
#   '2009': '35.95',
#   '2010': '89.48',
#   '2011': '41.14',
#   '2012': '33.36'},
#  {'_id': 90,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other assaults',
#   '2008': '2.37',
#   '2009': '2.95',
#   '2010': '4.69',
#   '2011': '6.63',
#   '2012': '3.9'},
#  {'_id': 91,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Unlawfully causing bodily harm',
#   '2008': '0.2',
#   '2009': '0.59',
#   '2010': '0.2',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 92,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing bodily harm',
#   '2008': '0.39',
#   '2009': '0.39',
#   '2010': '0.98',
#   '2011': '0.39',
#   '2012': '0'},
#  {'_id': 93,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other assaults',
#   '2008': '1.78',
#   '2009': '1.96',
#   '2010': '3.52',
#   '2011': '6.04',
#   '2012': '3.9'},
#  {'_id': 94,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total firearms; use of, discharge, pointing',
#   '2008': '3.95',
#   '2009': '4.71',
#   '2010': '7.62',
#   '2011': '5.65',
#   '2012': '9.36'},
#  {'_id': 95,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Discharge firearm with intent',
#   '2008': '2.76',
#   '2009': '2.36',
#   '2010': '3.13',
#   '2011': '0.97',
#   '2012': '2.93'},
#  {'_id': 96,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Using firearm in commission of offence',
#   '2008': '0',
#   '2009': '0.79',
#   '2010': '1.76',
#   '2011': '2.53',
#   '2012': '3.51'},
#  {'_id': 97,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Pointing a firearm',
#   '2008': '1.18',
#   '2009': '1.57',
#   '2010': '2.74',
#   '2011': '2.14',
#   '2012': '2.93'},
#  {'_id': 98,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total robbery (18)',
#   '2008': '27.06',
#   '2009': '22.79',
#   '2010': '31.65',
#   '2011': '21.45',
#   '2012': '27.7'},
#  {'_id': 99,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery (18)',
#   '2008': '27.06',
#   '2009': '22.79',
#   '2010': '31.65',
#   '2011': '21.45',
#   '2012': '27.7'},
#  {'_id': 100,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Robbery to steal a firearm (18)',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 101,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total forcible confinement or kidnapping (34)',
#   '2008': '8.49',
#   '2009': '10.8',
#   '2010': '11.14',
#   '2011': '6.63',
#   '2012': '7.02'},
#  {'_id': 102,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement or kidnapping (34)',
#   '2008': '8.49',
#   '2009': '10.8',
#   '2010': '9.96',
#   '2011': '1.56',
#   '2012': '0'},
#  {'_id': 103,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Kidnapping (34)',
#   '2008': None,
#   '2009': None,
#   '2010': '0.2',
#   '2011': '0.19',
#   '2012': '0.2'},
#  {'_id': 104,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement (34)',
#   '2008': None,
#   '2009': None,
#   '2010': '0.98',
#   '2011': '4.87',
#   '2012': '6.83'},
#  {'_id': 105,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total abduction',
#   '2008': '1.38',
#   '2009': '0.59',
#   '2010': '1.17',
#   '2011': '1.95',
#   '2012': '1.17'},
#  {'_id': 106,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14, not parent or guardian',
#   '2008': '0.39',
#   '2009': '0.39',
#   '2010': '0.39',
#   '2011': '0.78',
#   '2012': '0.98'},
#  {'_id': 107,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 16',
#   '2008': '0.2',
#   '2009': '0',
#   '2010': '0.2',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 108,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Removal of children from Canada',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 109,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14 contravening a custody order',
#   '2008': '0.59',
#   '2009': '0',
#   '2010': '0.39',
#   '2011': '0',
#   '2012': '0.2'},
#  {'_id': 110,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under age 14, by parent or guardian',
#   '2008': '0.2',
#   '2009': '0.2',
#   '2010': '0.2',
#   '2011': '0.97',
#   '2012': '0'},
#  {'_id': 111,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Extortion',
#   '2008': '0.59',
#   '2009': '0',
#   '2010': '1.76',
#   '2011': '1.36',
#   '2012': '0.78'},
#  {'_id': 112,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal harassment (36)',
#   '2008': '38.91',
#   '2009': '44.98',
#   '2010': '43.57',
#   '2011': '40.75',
#   '2012': '39.21'},
#  {'_id': 113,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Uttering threats',
#   '2008': '349.16',
#   '2009': '358.48',
#   '2010': '374.9',
#   '2011': '385.65',
#   '2012': '389.73'},
#  {'_id': 114,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Threatening or harassing phone calls',
#   '2008': '154.04',
#   '2009': '106.66',
#   '2010': '95.14',
#   '2011': '96.32',
#   '2012': '68.27'},
#  {'_id': 115,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violent violations',
#   '2008': '13.82',
#   '2009': '9.82',
#   '2010': '4.88',
#   '2011': '6.43',
#   '2012': '6.63'},
#  {'_id': 116,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Conspire to commit murder',
#   '2008': '0.2',
#   '2009': '0.39',
#   '2010': '0',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 117,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other sexual violations',
#   '2008': '10.86',
#   '2009': '6.29',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 118,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual Exploitation of a person with a disability',
#   '2008': '0',
#   '2009': '0.2',
#   '2010': '0',
#   '2011': '0.39',
#   '2012': '0.2'},
#  {'_id': 119,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Incest',
#   '2008': '0',
#   '2009': '0.2',
#   '2010': '0.98',
#   '2011': '0.19',
#   '2012': '0.98'},
#  {'_id': 120,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Corrupting morals of a child',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0.2'},
#  {'_id': 121,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Anal intercourse',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0.2',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 122,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Bestiality, commit or compel person',
#   '2008': '0.2',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0.39',
#   '2012': '0'},
#  {'_id': 123,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Voyeurism',
#   '2008': '0',
#   '2009': '0.59',
#   '2010': '0.59',
#   '2011': '0.58',
#   '2012': '0.78'},
#  {'_id': 124,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trap likely to or causing bodily harm',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 125,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Hostage-taking',
#   '2008': '0',
#   '2009': '0.39',
#   '2010': '1.17',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 126,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trafficking in persons',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 127,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a justice system participant or a journalist',
#   '2008': '0.39',
#   '2009': '0',
#   '2010': '0.59',
#   '2011': '0.19',
#   '2012': '0.59'},
#  {'_id': 128,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a non-justice participant',
#   '2008': '0',
#   '2009': '0.2',
#   '2010': '0.2',
#   '2011': '0.97',
#   '2012': '0.59'},
#  {'_id': 129,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Explosives causing death or bodily harm',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0.2',
#   '2011': '0.58',
#   '2012': '0'},
#  {'_id': 130,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Arson, disregard for human life',
#   '2008': '0.59',
#   '2009': '0.59',
#   '2010': '0',
#   '2011': '0.78',
#   '2012': '0.59'},
#  {'_id': 131,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Newfoundland and Labrador',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other violent violations',
#   '2008': '1.58',
#   '2009': '0.98',
#   '2010': '0.98',
#   '2011': '2.14',
#   '2012': '2.73'},
#  {'_id': 132,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#   '2008': '1142.26',
#   '2009': '1264.76',
#   '2010': '1173.49',
#   '2011': '1143.48',
#   '2012': '1168.34'},
#  {'_id': 133,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#   '2008': '1.43',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0.69',
#   '2012': '0'},
#  {'_id': 134,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0.69',
#   '2012': '0'},
#  {'_id': 135,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 136,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#   '2008': '1.43',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 137,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 138,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 139,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 140,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 141,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#   '2008': '0.72',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0.68'},
#  {'_id': 142,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 143,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#   '2008': '0',
#   '2009': '1.42',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0.68'},
#  {'_id': 144,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#   '2008': '55.18',
#   '2009': '43.95',
#   '2010': '42.63',
#   '2011': '50.79',
#   '2012': '49.96'},
#  {'_id': 145,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#   '2008': '1.43',
#   '2009': '12.76',
#   '2010': '16.77',
#   '2011': '13.04',
#   '2012': '15.74'},
#  {'_id': 146,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#   '2008': '0',
#   '2009': '11.34',
#   '2010': '9.78',
#   '2011': '6.86',
#   '2012': '6.16'},
#  {'_id': 147,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '1.37',
#   '2012': '4.11'},
#  {'_id': 148,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0.68'},
#  {'_id': 149,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#   '2008': None,
#   '2009': None,
#   '2010': None,
#   '2011': None,
#   '2012': '0'},
#  {'_id': 150,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#   '2008': '1.43',
#   '2009': '1.42',
#   '2010': '6.99',
#   '2011': '4.8',
#   '2012': '4.79'},
#  {'_id': 151,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#   '2008': '1.43',
#   '2009': '4.96',
#   '2010': '4.19',
#   '2011': '4.8',
#   '2012': '2.05'},
#  {'_id': 152,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#   '2008': '75.24',
#   '2009': '73.73',
#   '2010': '85.27',
#   '2011': '88.54',
#   '2012': '72.55'},
#  {'_id': 153,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 1',
#   '2008': '483.7',
#   '2009': '505.48',
#   '2010': '465.48',
#   '2011': '479.77',
#   '2012': '526.33'},
#  {'_id': 154,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total assaults against a peace officer (25,35)',
#   '2008': '9.32',
#   '2009': '28.36',
#   '2010': '31.45',
#   '2011': '13.04',
#   '2012': '12.32'},
#  {'_id': 155,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other assaults',
#   '2008': '1.43',
#   '2009': '0.71',
#   '2010': '0',
#   '2011': '0',
#   '2012': '1.37'},
#  {'_id': 156,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Unlawfully causing bodily harm',
#   '2008': '0.72',
#   '2009': '0.71',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0.68'},
#  {'_id': 157,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing bodily harm',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 158,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other assaults',
#   '2008': '0.72',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0.68'},
#  {'_id': 159,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total firearms; use of, discharge, pointing',
#   '2008': '1.43',
#   '2009': '1.42',
#   '2010': '2.1',
#   '2011': '2.06',
#   '2012': '2.74'},
#  {'_id': 160,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Discharge firearm with intent',
#   '2008': '0.72',
#   '2009': '0.71',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 161,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Using firearm in commission of offence',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0.7',
#   '2011': '0',
#   '2012': '0.68'},
#  {'_id': 162,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Prince Edward Island (51)',
# ...
#   '2009': None,
#   '2010': '0.96',
#   '2011': '0.38',
#   '2012': '0'},
#  {'_id': 949,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Forcible confinement (34)',
#   '2008': None,
#   '2009': None,
#   '2010': '3.25',
#   '2011': '9.81',
#   '2012': '8.2'},
#  {'_id': 950,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total abduction',
#   '2008': '0.59',
#   '2009': '1.35',
#   '2010': '1.53',
#   '2011': '0.19',
#   '2012': '0.56'},
#  {'_id': 951,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14, not parent or guardian',
#   '2008': '0.39',
#   '2009': '0.97',
#   '2010': '0.57',
#   '2011': '0',
#   '2012': '0.56'},
#  {'_id': 952,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 16',
#   '2008': '0',
#   '2009': '0.19',
#   '2010': '0.19',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 953,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Removal of children from Canada',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 954,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under the age 14 contravening a custody order',
#   '2008': '0.2',
#   '2009': '0.19',
#   '2010': '0.19',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 955,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Abduction under age 14, by parent or guardian',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0.57',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 956,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Extortion',
#   '2008': '3.71',
#   '2009': '5.22',
#   '2010': '3.82',
#   '2011': '3.77',
#   '2012': '2.42'},
#  {'_id': 957,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal harassment (36)',
#   '2008': '100.28',
#   '2009': '100.95',
#   '2010': '113.66',
#   '2011': '91.29',
#   '2012': '79.73'},
#  {'_id': 958,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Uttering threats',
#   '2008': '125.11',
#   '2009': '139.24',
#   '2010': '149.76',
#   '2011': '147.31',
#   '2012': '137.67'},
#  {'_id': 959,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Threatening or harassing phone calls',
#   '2008': '32.06',
#   '2009': '24.17',
#   '2010': '18.53',
#   '2011': '19.99',
#   '2012': '20.49'},
#  {'_id': 960,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violent violations',
#   '2008': '16.22',
#   '2009': '7.54',
#   '2010': '5.73',
#   '2011': '10.56',
#   '2012': '9.31'},
#  {'_id': 961,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Conspire to commit murder',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0.19',
#   '2012': '0'},
#  {'_id': 962,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other sexual violations',
#   '2008': '13.49',
#   '2009': '0.58',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 963,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual Exploitation of a person with a disability',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 964,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Incest',
#   '2008': '0',
#   '2009': '0.19',
#   '2010': '0.38',
#   '2011': '0.75',
#   '2012': '0.37'},
#  {'_id': 965,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Corrupting morals of a child',
#   '2008': '0',
#   '2009': '0.39',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 966,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Anal intercourse',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 967,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Bestiality, commit or compel person',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0.57',
#   '2012': '0'},
#  {'_id': 968,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Voyeurism',
#   '2008': '0.2',
#   '2009': '2.71',
#   '2010': '0.96',
#   '2011': '6.6',
#   '2012': '4.84'},
#  {'_id': 969,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trap likely to or causing bodily harm',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 970,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Hostage-taking',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 971,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Trafficking in persons',
#   '2008': None,
#   '2009': None,
#   '2010': '0.38',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 972,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a justice system participant or a journalist',
#   '2008': '0.39',
#   '2009': '0.58',
#   '2010': '0.38',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 973,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Intimidation of a non-justice participant',
#   '2008': '0',
#   '2009': '0.19',
#   '2010': '0.57',
#   '2011': '1.7',
#   '2012': '0.93'},
#  {'_id': 974,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Explosives causing death or bodily harm',
#   '2008': '0.2',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 975,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Arson, disregard for human life',
#   '2008': '0.59',
#   '2009': '1.35',
#   '2010': '1.53',
#   '2011': '0.19',
#   '2012': '1.86'},
#  {'_id': 976,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Kitchener-Cambridge-Waterloo, Ontario',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other violent violations',
#   '2008': '1.37',
#   '2009': '1.55',
#   '2010': '1.53',
#   '2011': '0.57',
#   '2012': '1.3'},
#  {'_id': 977,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total violent Criminal Code violations (16)',
#   '2008': '1629.39',
#   '2009': '1692.62',
#   '2010': '1640.97',
#   '2011': '1443.26',
#   '2012': '1321.5'},
#  {'_id': 978,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Homicide (17,24)',
#   '2008': '1.45',
#   '2009': '1.44',
#   '2010': '0.72',
#   '2011': '1.42',
#   '2012': '0'},
#  {'_id': 979,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, first degree (17,24)',
#   '2008': '0',
#   '2009': '1.44',
#   '2010': '0',
#   '2011': '0.71',
#   '2012': '0'},
#  {'_id': 980,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Murder, second degree (17,24)',
#   '2008': '1.45',
#   '2009': '0',
#   '2010': '0.72',
#   '2011': '0.71',
#   '2012': '0'},
#  {'_id': 981,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Manslaughter (17,24)',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 982,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Infanticide (17,24)',
#   '2008': None,
#   '2009': None,
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 983,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other violations causing death',
#   '2008': '0',
#   '2009': '0.72',
#   '2010': '0.72',
#   '2011': '0.71',
#   '2012': '0.71'},
#  {'_id': 984,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Criminal negligence causing death',
#   '2008': '0',
#   '2009': '0.72',
#   '2010': '0.72',
#   '2011': '0.71',
#   '2012': '0.71'},
#  {'_id': 985,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Other related violations causing death',
#   '2008': '0',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 986,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Attempted murder',
#   '2008': '2.18',
#   '2009': '2.88',
#   '2010': '2.15',
#   '2011': '2.14',
#   '2012': '1.42'},
#  {'_id': 987,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 3, aggravated',
#   '2008': '0.73',
#   '2009': '0',
#   '2010': '0',
#   '2011': '0',
#   '2012': '0.71'},
#  {'_id': 988,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 2, weapon or bodily harm',
#   '2008': '2.9',
#   '2009': '0.72',
#   '2010': '0.72',
#   '2011': '0.71',
#   '2012': '2.13'},
#  {'_id': 989,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual assault, level 1',
#   '2008': '82.7',
#   '2009': '93.67',
#   '2010': '85.27',
#   '2011': '94.74',
#   '2012': '68.73'},
#  {'_id': 990,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total sexual violations against children (26)',
#   '2008': '2.18',
#   '2009': '6.49',
#   '2010': '10.03',
#   '2011': '9.97',
#   '2012': '8.5'},
#  {'_id': 991,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual interference (26)',
#   '2008': '0',
#   '2009': '2.16',
#   '2010': '5.02',
#   '2011': '4.27',
#   '2012': '7.79'},
#  {'_id': 992,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Invitation to sexual touching (26)',
#   '2008': '0.73',
#   '2009': '2.16',
#   '2010': '2.87',
#   '2011': '4.27',
#   '2012': '0'},
#  {'_id': 993,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Sexual exploitation (26)',
#   '2008': '0.73',
#   '2009': '0',
#   '2010': '0.72',
#   '2011': '0',
#   '2012': '0'},
#  {'_id': 994,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Making sexually explicit material available to children (48)',
#   '2008': None,
#   '2009': None,
#   '2010': None,
#   '2011': None,
#   '2012': '0'},
#  {'_id': 995,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Luring a child via a computer (26)',
#   '2008': '0.73',
#   '2009': '2.16',
#   '2010': '1.43',
#   '2011': '1.42',
#   '2012': '0.71'},
#  {'_id': 996,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 3, aggravated',
#   '2008': '7.98',
#   '2009': '10.09',
#   '2010': '13.61',
#   '2011': '9.97',
#   '2012': '10.63'},
#  {'_id': 997,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 2, weapon or bodily harm',
#   '2008': '153.8',
#   '2009': '145.56',
#   '2010': '173.41',
#   '2011': '123.95',
#   '2012': '125.42'},
#  {'_id': 998,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Assault, level 1',
#   '2008': '692.82',
#   '2009': '682.38',
#   '2010': '688.63',
#   '2011': '641.13',
#   '2012': '586.7'},
#  {'_id': 999,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total assaults against a peace officer (25,35)',
#   '2008': '28.29',
#   '2009': '33.87',
#   '2010': '35.83',
#   '2011': '27.07',
#   '2012': '18.42'},
#  {'_id': 1000,
#   'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Brantford, Ontario (8)',
#   'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Total other assaults',
#   '2008': '18.86',
#   '2009': '37.47',
#   '2010': '56.61',
#   '2011': '29.92',
#   '2012': '37.55'},
#  ...]

# %%
# Convert and store those columns you selected into a dataframe
violent_crime_rate = pd.DataFrame(violent_cr_data)
print(violent_crime_rate)
# Out:
#        _id Geography (Footnotes in parentheses-see bottom of spreadsheet)  \
# 0        1  Geography (Footnotes in parentheses–see bottom...
# 1        2                                        Canada (50)
# 2        3                                        Canada (50)
# 3        4                                        Canada (50)
# 4        5                                        Canada (50)
# ...    ...                                                ...
# 1495  1496                                           Manitoba
# 1496  1497                                  Saskatchewan (11)
# 1497  1498                                  Saskatchewan (11)
# 1498  1499                                  Saskatchewan (11)
# 1499  1500                                  Saskatchewan (11)
#
#      Violations (Footnotes in parentheses-see bottom of spreadsheet)     2008  \
# 0     Violations (Footnotes in parentheses–see botto...                  2008
# 1           Total violent Criminal Code violations (16)               1331.45
# 2                                      Homicide (17,24)                  1.83
# 3                          Murder, first degree (17,24)                  0.88
# 4                         Murder, second degree (17,24)                  0.79
# ...                                                 ...                   ...
# 1495                           Other violent violations                  2.16
# 1496        Total violent Criminal Code violations (16)               2503.89
# 1497                                   Homicide (17,24)                  2.96
# 1498                       Murder, first degree (17,24)                  0.39
# 1499                      Murder, second degree (17,24)                  1.87
#
#          2009     2010     2011     2012
# 0        2009     2010     2011     2012
# 1     1318.04  1287.03  1230.54  1190.12
# 2        1.81     1.62     1.73     1.56
# 3        0.83     0.73     0.76      0.7
# 4        0.77      0.7     0.77     0.66
# ...       ...      ...      ...      ...
# 1495     2.79     4.45     2.64     2.68
# 1496   2518.7  2556.01  2384.18  2200.73
# 1497      3.5     3.26     3.59     2.69
# 1498     0.49     0.86     1.04     0.83
# 1499     2.14     2.01     1.89     1.57
#
# [1500 rows x 8 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Note: The values in columns 2008 to 2012 are rates. They represent the violent crime rate for each year for the type of violent crime shown in that row. The unit is (per 100,000 population)!!!

# %%
violent_crime_rate.head(5)
# Out:
#    _id Geography (Footnotes in parentheses-see bottom of spreadsheet)  \
# 0    1  Geography (Footnotes in parentheses–see bottom...
# 1    2                                        Canada (50)
# 2    3                                        Canada (50)
# 3    4                                        Canada (50)
# 4    5                                        Canada (50)
#
#   Violations (Footnotes in parentheses-see bottom of spreadsheet)     2008  \
# 0  Violations (Footnotes in parentheses–see botto...                  2008
# 1        Total violent Criminal Code violations (16)               1331.45
# 2                                   Homicide (17,24)                  1.83
# 3                       Murder, first degree (17,24)                  0.88
# 4                      Murder, second degree (17,24)                  0.79
#
#       2009     2010     2011     2012
# 0     2009     2010     2011     2012
# 1  1318.04  1287.03  1230.54  1190.12
# 2     1.81     1.62     1.73     1.56
# 3     0.83     0.73     0.76      0.7
# 4     0.77      0.7     0.77     0.66

# %% [markdown]
# #### Drop the first row of the dataset since it just replicate the column name

# %%
violent_crime_rate = violent_crime_rate.drop(violent_crime_rate.index[0])

# %%
violent_crime_rate
# Out:
#        _id Geography (Footnotes in parentheses-see bottom of spreadsheet)  \
# 1        2                                        Canada (50)
# 2        3                                        Canada (50)
# 3        4                                        Canada (50)
# 4        5                                        Canada (50)
# 5        6                                        Canada (50)
# ...    ...                                                ...
# 1495  1496                                           Manitoba
# 1496  1497                                  Saskatchewan (11)
# 1497  1498                                  Saskatchewan (11)
# 1498  1499                                  Saskatchewan (11)
# 1499  1500                                  Saskatchewan (11)
#
#      Violations (Footnotes in parentheses-see bottom of spreadsheet)     2008  \
# 1           Total violent Criminal Code violations (16)               1331.45
# 2                                      Homicide (17,24)                  1.83
# 3                          Murder, first degree (17,24)                  0.88
# 4                         Murder, second degree (17,24)                  0.79
# 5                                  Manslaughter (17,24)                  0.17
# ...                                                 ...                   ...
# 1495                           Other violent violations                  2.16
# 1496        Total violent Criminal Code violations (16)               2503.89
# 1497                                   Homicide (17,24)                  2.96
# 1498                       Murder, first degree (17,24)                  0.39
# 1499                      Murder, second degree (17,24)                  1.87
#
#          2009     2010     2011     2012
# 1     1318.04  1287.03  1230.54  1190.12
# 2        1.81     1.62     1.73     1.56
# 3        0.83     0.73     0.76      0.7
# 4        0.77      0.7     0.77     0.66
# 5        0.21     0.18      0.2     0.19
# ...       ...      ...      ...      ...
# 1495     2.79     4.45     2.64     2.68
# 1496   2518.7  2556.01  2384.18  2200.73
# 1497      3.5     3.26     3.59     2.69
# 1498     0.49     0.86     1.04     0.83
# 1499     2.14     2.01     1.89     1.57
#
# [1499 rows x 8 columns]

# %% [markdown]
# #### Change the name of the first column to 'Geography', and the name of the second column to 'Violations'

# %%
# change the name of the first column to 'Geography', and the name of the second column to 'Violations'
violent_crime_rate.rename(columns={'Geography (Footnotes in parentheses-see bottom of spreadsheet)': 'Geography', 'Violations (Footnotes in parentheses-see bottom of spreadsheet)': 'Violations'}, inplace=True)

# %%
violent_crime_rate.head(5)
# Out:
#    _id    Geography                                   Violations     2008  \
# 1    2  Canada (50)  Total violent Criminal Code violations (16)  1331.45
# 2    3  Canada (50)                             Homicide (17,24)     1.83
# 3    4  Canada (50)                 Murder, first degree (17,24)     0.88
# 4    5  Canada (50)                Murder, second degree (17,24)     0.79
# 5    6  Canada (50)                         Manslaughter (17,24)     0.17
#
#       2009     2010     2011     2012
# 1  1318.04  1287.03  1230.54  1190.12
# 2     1.81     1.62     1.73     1.56
# 3     0.83     0.73     0.76      0.7
# 4     0.77      0.7     0.77     0.66
# 5     0.21     0.18      0.2     0.19

# %%
# reset the index of the dataframe
violent_crime_rate.reset_index(drop=True, inplace=True)
# drop the first column
violent_crime_rate = violent_crime_rate.drop(violent_crime_rate.columns[0], axis=1)

# %%
violent_crime_rate.head(2)
# Out:
#      Geography                                   Violations     2008     2009  \
# 0  Canada (50)  Total violent Criminal Code violations (16)  1331.45  1318.04
# 1  Canada (50)                             Homicide (17,24)     1.83     1.81
#
#       2010     2011     2012
# 0  1287.03  1230.54  1190.12
# 1     1.62     1.73     1.56

# %% [markdown]
# #### Extract only the records with geography as 'Toronto'

# %%
# We only want to the violent crime rates that were took place in Toronto, Ontario
# In this case, we need to pull data on violent crime rate related to Toronto, Ontario (33) only.
toronto_crime_rate = violent_crime_rate[violent_crime_rate['Geography'] == 'Toronto, Ontario (33)']

# %%
toronto_crime_rate
# Out:
#                  Geography                                         Violations  \
# 715  Toronto, Ontario (33)        Total violent Criminal Code violations (16)
# 716  Toronto, Ontario (33)                                   Homicide (17,24)
# 717  Toronto, Ontario (33)                       Murder, first degree (17,24)
# 718  Toronto, Ontario (33)                      Murder, second degree (17,24)
# 719  Toronto, Ontario (33)                               Manslaughter (17,24)
# ..                     ...                                                ...
# 775  Toronto, Ontario (33)  Intimidation of a justice system participant o...
# 776  Toronto, Ontario (33)          Intimidation of a non-justice participant
# 777  Toronto, Ontario (33)            Explosives causing death or bodily harm
# 778  Toronto, Ontario (33)                    Arson, disregard for human life
# 779  Toronto, Ontario (33)                           Other violent violations
#
#        2008    2009    2010    2011    2012
# 715  986.09  940.71  906.28  873.06  809.12
# 716    1.87    1.61    1.41    1.48    1.36
# 717    1.07    1.02    0.97    0.71    0.78
# 718    0.76    0.48    0.42    0.64    0.54
# 719    0.04    0.11    0.02    0.14    0.03
# ..      ...     ...     ...     ...     ...
# 775    0.31    0.34     0.4    0.41    0.44
# 776    0.02    0.18    0.14    0.21    0.07
# 777       0       0       0       0       0
# 778    0.62    0.91    0.83    0.71     0.7
# 779    2.62    1.86    2.16    1.83    1.51
#
# [65 rows x 7 columns]

# %%
toronto_crime_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65 entries, 715 to 779
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Geography   65 non-null     object
#  1   Violations  65 non-null     object
#  2   2008        64 non-null     object
#  3   2009        64 non-null     object
#  4   2010        64 non-null     object
#  5   2011        64 non-null     object
#  6   2012        65 non-null     object
# dtypes: object(7)
# memory usage: 4.1+ KB

# %%
# reset the index of the toronto_crime_rate dataframe
toronto_crime_rate.reset_index(drop=True, inplace=True)

# %%
toronto_crime_rate.isnull().sum()
# Out:
# Geography     0
# Violations    0
# 2008          1
# 2009          1
# 2010          1
# 2011          1
# 2012          0
# dtype: int64

# %%
# Since the number of rows containing missing value are small, we could drop those record with missing value
toronto_crime_rate = toronto_crime_rate.dropna()

# %% [markdown]
# #### Feature engineering

# %%
toronto_crime_rate['2008'] = toronto_crime_rate['2008'].astype(float)
toronto_crime_rate['2009'] = toronto_crime_rate['2009'].astype(float)
toronto_crime_rate['2010'] = toronto_crime_rate['2010'].astype(float)
toronto_crime_rate['2011'] = toronto_crime_rate['2011'].astype(float)
toronto_crime_rate['2012'] = toronto_crime_rate['2012'].astype(float)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
toronto_crime_rate['Average_crime_rate'] = toronto_crime_rate[['2008', '2009', '2010', '2011', '2012']].mean(axis=1)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
toronto_crime_rate.head()
# Out:
#                Geography                                   Violations    2008  \
# 0  Toronto, Ontario (33)  Total violent Criminal Code violations (16)  986.09
# 1  Toronto, Ontario (33)                             Homicide (17,24)    1.87
# 2  Toronto, Ontario (33)                 Murder, first degree (17,24)    1.07
# 3  Toronto, Ontario (33)                Murder, second degree (17,24)    0.76
# 4  Toronto, Ontario (33)                         Manslaughter (17,24)    0.04
#
#      2009    2010    2011    2012  Average_crime_rate
# 0  940.71  906.28  873.06  809.12             903.052
# 1    1.61    1.41    1.48    1.36               1.546
# 2    1.02    0.97    0.71    0.78               0.910
# 3    0.48    0.42    0.64    0.54               0.568
# 4    0.11    0.02    0.14    0.03               0.068

# %%
# Convert violations column into string
toronto_crime_rate['Violations'] = toronto_crime_rate['Violations'].astype(str)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# remove the brackets and everything in between from the values in column Violation.
toronto_crime_rate['Violations'] = toronto_crime_rate['Violations'].str.replace(r'\(.*?\)', '')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Convert Geography into string
toronto_crime_rate['Geography'] = toronto_crime_rate['Geography'].astype(str)

# remove the brackets and everything in between from the values in column Geography.
toronto_crime_rate['Geography'] = toronto_crime_rate['Geography'].str.replace(r'\(.*?\)', '')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
toronto_crime_rate.head()
# Out:
#            Geography                               Violations    2008    2009  \
# 0  Toronto, Ontario   Total violent Criminal Code violations   986.09  940.71
# 1  Toronto, Ontario                                 Homicide     1.87    1.61
# 2  Toronto, Ontario                     Murder, first degree     1.07    1.02
# 3  Toronto, Ontario                    Murder, second degree     0.76    0.48
# 4  Toronto, Ontario                             Manslaughter     0.04    0.11
#
#      2010    2011    2012  Average_crime_rate
# 0  906.28  873.06  809.12             903.052
# 1    1.41    1.48    1.36               1.546
# 2    0.97    0.71    0.78               0.910
# 3    0.42    0.64    0.54               0.568
# 4    0.02    0.14    0.03               0.068

# %% [markdown]
# ### Insert data into our database

# %% [markdown]
# ### Database Credential

# %%
import sqlalchemy as sa
import pandas as pd

# %%
my_db_secret = {
    'drivername' : 'postgresql+psycopg2',
    'host'       : 'mmai5100postgres.canadacentral.cloudapp.azure.com',
    'port'       : '5432',
    'username'   : 'kevli88',
    'password'   : '2023!Schulich',
    'database'   : 'kevli88_db'
}

# %% [markdown]
# ### Database URL

# %%
my_db_url = sa.engine.URL.create(
    drivername = my_db_secret['drivername'],
    username   = my_db_secret['username'],
    password   = my_db_secret['password'],
    host       = my_db_secret['host'],
    port       = my_db_secret['port'],
    database   = my_db_secret['database']
)

# %% [markdown]
# ### Create a sqlalchemy Engine

# %%
my_db_engine = sa.create_engine(my_db_url)

# %% [markdown]
# ### Create a new schema in our own database using the new Engine

# %%
with my_db_engine.connect() as connection:
    connection.execute('CREATE SCHEMA IF NOT EXISTS assignment_2;')

# %% [markdown]
# ### Insert our data 'toronto_crime_rate' into the schema we created in DataGrip database

# %%
toronto_crime_rate.to_sql(
    name      = 'toronto_crime_rate',
    con       = my_db_engine,
    schema    = 'assignment_2',
    if_exists = 'replace',
    index     = False,
    dtype     = {
        'Geography' : sa.types.VARCHAR(255),
        'Violations' : sa.types.VARCHAR(255),
        '2008' : sa.types.DECIMAL(10,2),
        '2009' : sa.types.DECIMAL(10,2),
        '2010' : sa.types.DECIMAL(10,2),
        '2011' : sa.types.DECIMAL(10,2),
        '2012' : sa.types.DECIMAL(10,2),
        'Average_crime_rate' : sa.types.DECIMAL(10,3)
    },
    method = 'multi'
)
